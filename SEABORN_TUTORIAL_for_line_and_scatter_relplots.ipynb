# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagu12/all-projects/blob/master/SEABORN_TUTORIAL_for_line_and_scatter_relplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyforest

#this library imports all the necessary libraries
# Out:
# ...
#   Created wheel for pyforest: filename=pyforest-1.0.3-py2.py3-none-any.whl size=13715 sha256=69c24ae9abce43691c5d6f0bf8f639584761e4ec509bf5350ddf980c758ebfcf
#   Stored in directory: /root/.cache/pip/wheels/af/0b/39/340a7f15fc8d4ff5ab50847b28789afea04452a9d51b9721b5
# Successfully built pyforest
# ...

# %%
from pyforest import *

# %%
df= pd.DataFrame(np.random.rand(5))

# %%
#Video Object Removal
#DeepPrivacy – An Impressive Anonymization Technique for Images

#https://www.analyticsvidhya.com/blog/2019/12/30-challenging-open-source-data-science-projects-2020/

# %%
df
# Out:
#           0
# 0  0.264744
# 1  0.065539
# 2  0.640618
# 3  0.243086
# 4  0.933455

# %% [markdown]
# #what is statistics?
#
# statistical analysis is a process of understanding how variables in a dataset relate to each other and how these relationships depend on other variables. vizualisation can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# #types of plotting that can be done with the help of seaborn library and also the types of plots mainly present in statistical analysis
#
# 1. Numerical data plotting
# relplot()
# scatterplot()
# lineplot()
#
# 2. Categorical data plotting
# catplot()
# boxplot()
# stripplot()
# swarmplot() and many more....
#
# 3. Visualizing distribution of the data
# distplot()
# kdeplot()
# jointplot()
# rugplot()
#
# 4. liinear regression and relationship
# regplot()
# implot()
#
# 5. controlling plotted figure aesthetics
# figure styling
# axes styling
# color palettes

# %%
sns.set(style="darkgrid")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#plotting a relational plot to define the relatrionship of getting a tip based on the bill

# %%
sns.relplot(x="total_bill", y="tip", data=tips)

#by this graph we can say somehow there is a linear relationship between the two variables

#facetgrid means plotting many axes on a single figure

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_clean_axis',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'map',
#  'map_dataframe',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels']

# %%
tips["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="smoker")

# %%
#https://pythonexamples.org/convert-pandas-dataframe-to-numpy-array/

#https://www.geeksforgeeks.org/python-pandas-dataframe-values/

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="sex")
sns.relplot(x="total_bill", y="tip", data=tips, hue="time", style="sex")

# %%
#https://www.geeksforgeeks.org/python-string-count/

# %%
#plotting with same color but different intensity

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips)

#this is called qualitative palettes as we are dealing only with numerical data and when we deal with categorical data it is called categorical palettes

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips,palette = "ch:r=0.8, l=0.5")
#changing the colors using palette

# %%
#increasing the size of markers according to increase in value

# %%
sns.relplot(x="total_bill", y="tip",size="size", data=tips,palette = "ch:r=0.8, l=0.5")

# %%
sns.relplot(x="total_bill", y="tip",size="size", data=tips,palette = "ch:r=0.6, l=0.9", sizes=(15,200))

# %%
#Line plot

# %%
from numpy.random import randn

# %%
df= pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0  0.484725
# 1     1  2.549208
# 2     2  3.230858
# 3     3  4.712001
# 4     4  3.499322

# %%
sns.relplot(x="time", y="value", data=df, kind="line")

# %%
df= df.sort_values("value", axis=0, ascending=True)

# %%
df
# Out:
#      time      value
# 100   100 -10.220375
# 101   101  -9.676832
# 98     98  -9.342587
# 97     97  -9.124000
# 96     96  -9.029068
# ..    ...        ...
# 362   362  21.319295
# 368   368  21.449425
# 369   369  22.001401
# 361   361  22.308791
# 363   363  22.494843
#
# [500 rows x 2 columns]

# %%
sns.relplot(x="time", y="value", data=df, kind="line")

#this graph is based on sorting of values and the previous one was based on sorting of time

# %%
#how to reset index in pandas--->https://datatofish.com/reset-index-pandas-dataframe/

# %%
randn(500,2)

# %%
df2= pd.DataFrame(randn(500,2).cumsum(axis=0), columns= ["time", "value"])

# %%
df2.head()
# Out:
#        time     value
# 0 -0.588184  1.444519
# 1 -0.636618  1.741947
# 2  0.291372  1.795105
# 3 -0.795502  0.705950
# 4 -1.610399 -0.025687

# %%
sns.relplot(x="time", y="value", data=df2, kind="line", sort=False)

# %%
sns.relplot(x="time", y="value", data=df2, kind="line", sort=True)
#above and below we have mainly shown the graphs based on sorting and desorting based on time and value

# %%
fmri= sns.load_dataset("fmri")

fmri.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
sns.relplot(x="timepoint", y="signal", data=fmri, kind="line")

# %%
#the blurred line represents the confidence level of the data and says that the range of the bold line lies within this confidence level

# %%
#to close the confidence level we need to do the following

# %%
sns.relplot(x="timepoint", y="signal", data=fmri, kind="line", ci=False)

# %%
#plotting with std deviation

sns.relplot(x="timepoint", y="signal", data=fmri, kind="line", ci="sd")

# %%
#plotting the real data

sns.relplot(x="timepoint", y="signal", data=fmri, kind="line", estimator=None)

# %%
#tips of how to standardize variables manually

#ypically, to standardize variables, you calculate the mean and standard deviation for a variable. Then, for each observed value of the variable, you subtract the mean and divide by the standard deviation

# %%
#Using hue, style and size for plotting the graph that is using semantically similar values to plot the graph for a better vizualization

# %%
sns.relplot(x="timepoint", y="signal", data=fmri, kind="line", hue="event")

# %%
sns.relplot(x="timepoint", y="signal", data=fmri, kind="line", hue="region", style="event", ci=None)

# %%
#removing the dashes and using markers for proper distinguishing
sns.relplot(x="timepoint", y="signal", data=fmri, kind="line", hue="region", style="event", ci=None, markers=True, dashes=False)

# %%
#plotting multiple line plots based on different subjects in the dataset of fmri in a graph and using only stim as the measuring parameter

# %%
sns.relplot(x="timepoint", y="signal",  kind="line",units="subject", hue="region", style="event", ci=None, markers=True, dashes=False, estimator=None, data= fmri.query("event=='stim'"))

# %%
#changing the colormap from default to custom by loading a different dataset from seaborn

# %%
dots= sns.load_dataset("dots").query("align=='dots'")

# %%
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
sns.relplot(x="time", y="firing_rate", data=dots, kind="line", hue="coherence", style="choice")

# %%
palette= sns.cubehelix_palette(light=0.5, n_colors=6)
sns.relplot(x="time", y="firing_rate", data=dots, kind="line", hue="coherence", style="choice", palette=palette)
