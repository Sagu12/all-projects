# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
df= pd.read_csv("/content/2015_2_clickstream.tsv", sep="\t")[0:1000000]

# %%
df.head()
# Out:
#    prev_id    curr_id    n          prev_title curr_title   type
# 0      NaN  3632887.0  121        other-google         !!  other
# 1      NaN  3632887.0   93     other-wikipedia         !!  other
# 2      NaN  3632887.0   46         other-empty         !!  other
# 3      NaN  3632887.0   10         other-other         !!  other
# 4  64486.0  3632887.0   11  !_(disambiguation)         !!  other

# %%
import re
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data= df.drop(["prev_id", "curr_id", "n", "curr_title"], axis=1)
data.head()
# Out:
#            prev_title   type
# 0        other-google  other
# 1     other-wikipedia  other
# 2         other-empty  other
# 3         other-other  other
# 4  !_(disambiguation)  other

# %%
data["prev_title"]= data["prev_title"].astype("str")

# %%
def clean_text(d):
    all_reviews = list()
    lines = d["prev_title"].values.tolist()
    for text in lines:
        text = text.lower()
        
        pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
        text = pattern.sub('', text)
        
        emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
        text = emoji.sub(r'', text)
        
        text = re.sub(r"i'm", "i am", text)
        text = re.sub(r"he's", "he is", text)
        text = re.sub(r"she's", "she is", text)
        text = re.sub(r"that's", "that is", text)        
        text = re.sub(r"what's", "what is", text)
        text = re.sub(r"where's", "where is", text) 
        text = re.sub(r"\'ll", " will", text)  
        text = re.sub(r"\'ve", " have", text)  
        text = re.sub(r"\'re", " are", text)
        text = re.sub(r"\'d", " would", text)
        text = re.sub(r"\'ve", " have", text)
        text = re.sub(r"won't", "will not", text)
        text = re.sub(r"don't", "do not", text)
        text = re.sub(r"did't", "did not", text)
        text = re.sub(r"can't", "can not", text)
        text = re.sub(r"it's", "it is", text)
        text = re.sub(r"couldn't", "could not", text)
        text = re.sub(r"have't", "have not", text)
        
        text = re.sub(r"[,.\"!@#$%^&*(){}?/;`~:<>+=-]", " ", text)
        tokens = word_tokenize(text)
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        words = [word for word in stripped if word.isalpha()]
#         stop_words = set(stopwords.words("english"))
#         stop_words.discard("not")
#         words = [w for w in words if not w in stop_words]
        words = ' '.join(words)
        all_reviews.append(words)
    return all_reviews

all_reviews = clean_text(data)
all_reviews[0:20]
# Out:
# ['other google',
#  'other wikipedia',
#  'other empty',
#  'other other',
#  'disambiguation',
#  'loudenupnow',
#  'other empty',
#  'other google',
#  'other wikipedia',
#  'disambiguation',
#  '',
#  'other empty',
#  'hero',
#  'other wikipedia',
#  'other google',
#  'jerichorosales',
#  'listoftelenovelasofabs cbn',
#  'other google',
#  'other wikipedia',
#  'other empty']

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"

# %%
model = hub.load(module_url)

# %%
sentence_embeddings = model(all_reviews)
query = "I had pizza and pasta"
query_vec = model([query])[0]

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
for sent in all_reviews:
  sim = cosine(query_vec, model([sent])[0])
  print("Sentence = ", sent, "; similarity = ", sim)
# Out:
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  disambiguation ; similarity =  -0.020961016
# Sentence =  loudenupnow ; similarity =  0.09295138
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  disambiguation ; similarity =  -0.020961016
# Sentence =   ; similarity =  0.054741997
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  hero ; similarity =  0.053547896
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  jerichorosales ; similarity =  0.036781814
# Sentence =  listoftelenovelasofabs cbn ; similarity =  0.010826356
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  ricaperalejo ; similarity =  -0.027942719
# Sentence =  jeepneytv ; similarity =  0.09794399
# Sentence =  okatokat ; similarity =  0.051066943
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  listofdeathmetalbands ; similarity =  -0.009272207
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  thedismembermentplan ; similarity =  0.028173504
# Sentence =  thedismembermentplanisterrified ; similarity =  0.054960698
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  unitedstatesmilitaryawarddevices ; similarity =  0.028079275
# Sentence =  ussyorktown cv ; similarity =  0.1197963
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  americandefenseservicemedal ; similarity =  -0.037158575
# Sentence =  overseasserviceribbon ; similarity =  0.044928163
# Sentence =  ussranger cv ; similarity =  0.16708502
# Sentence =  antarcticaservicemedal ; similarity =  0.06247935
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  wisforwasted ; similarity =  0.015353714
# Sentence =  and ; similarity =  -0.021875786
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other other ; similarity =  0.030498616
# Sentence =   ; similarity =  0.054741997
# Sentence =  visforvagina ; similarity =  0.003511672
# Sentence =  themission ; similarity =  0.039764438
# Sentence =  trentreznordiscography ; similarity =  0.022840703
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  tapeworm band ; similarity =  0.12549053
# Sentence =  millajovovich ; similarity =  0.010977548
# Sentence =  soundintobloodintowine ; similarity =  0.09073556
# Sentence =  carinaround ; similarity =  0.013305334
# Sentence =  conditionsofmyparole ; similarity =  0.074451126
# Sentence =  timalexander ; similarity =  -0.017874109
# Sentence =  puscifer ; similarity =  0.036914762
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  tết ; similarity =  -0.008446892
# Sentence =  listofoldwestgunfighters ; similarity =  0.05825325
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other twitter ; similarity =  0.034404803
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  listofacademyawardsceremonies ; similarity =  -0.03873739
# Sentence =  listofaustralianfilms ; similarity =  0.16728793
# Sentence =  crocodiledundeeinlosangeles ; similarity =  0.059293568
# Sentence =  bobbyalto ; similarity =  -0.018197952
# Sentence =  bazluhrmann ; similarity =  0.010281238
# Sentence =  australia ; similarity =  -0.037967246
# Sentence =   ; similarity =  0.054741997
# Sentence =   ; similarity =  0.054741997
# Sentence =  crocodiledundeeii ; similarity =  0.031172873
# Sentence =  caitlinclarke ; similarity =  -0.033917774
# Sentence =  dundee disambiguation ; similarity =  0.006198859
# Sentence =   ; similarity =  0.054741997
# Sentence =  australiannewwave ; similarity =  0.062571734
# Sentence =  davidgulpilil ; similarity =  0.06792439
# Sentence =  crocodilehunter ; similarity =  -0.009939655
# Sentence =  crocodilia ; similarity =  0.037475977
# Sentence =  listofmostwatchedtelevisionbroadcasts ; similarity =  0.020085322
# Sentence =  annecarlisle ; similarity =  0.010646508
# Sentence =  bartvs australia ; similarity =  -0.047878318
# Sentence =  cinemaofaustralia ; similarity =  0.04889798
# Sentence =   ; similarity =  0.054741997
# Sentence =  bowieknife ; similarity =  0.027318707
# Sentence =  crocodile ; similarity =  0.0899594
# Sentence =   ; similarity =  0.054741997
# Sentence =  academyawardforbestoriginalscreenplay ; similarity =  0.007419401
# Sentence =  boy scoutznthehood ; similarity =  0.016583553
# Sentence =  comedyfilm ; similarity =  0.03278135
# Sentence =  listoffilmssetinnewyorkcity ; similarity =  -0.02222565
# Sentence =  listoffilmssetinaustralia ; similarity =  -0.0394559
# Sentence =  hellokittysfurrytaletheater ; similarity =  0.08258432
# Sentence =  lindakozlowski ; similarity =  0.08646043
# Sentence =  listofparamountpicturesfilms ; similarity =  0.015856111
# Sentence =   ; similarity =  0.054741997
# Sentence =  johnmeillon ; similarity =  0.025622265
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  therescuersdownunder ; similarity =  -0.0060084057
# Sentence =  youngeinstein ; similarity =  0.054408707
# Sentence =  themanfromsnowyriver ; similarity =  -0.008282171
# Sentence =  skippythebushkangaroo ; similarity =  0.083523355
# Sentence =  michael crocodile dundee ; similarity =  0.051566552
# Sentence =  paulhogan ; similarity =  0.033923727
# Sentence =  saltwatercrocodile ; similarity =  0.0570411
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  peterbest composer ; similarity =  0.05162624
# Sentence =  reginaldveljohnson ; similarity =  0.0011672898
# Sentence =  plazahotel ; similarity =  -0.091278456
# Sentence =  liveitup mentalasanythingsong ; similarity =  0.0481861
# Sentence =  mainpage ; similarity =  0.07606527
# Sentence =  mentalasanything ; similarity =  0.03270511
# Sentence =  paulgreco ; similarity =  0.0929907
# Sentence =  paramountpictures ; similarity =  -0.08466562
# Sentence =  rodneyansell ; similarity =  0.005335975
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  steveirwin ; similarity =  0.059886806
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  startrekiv thevoyagehome ; similarity =  -0.018540572
# Sentence =  terrygill ; similarity =  0.09553088
# Sentence =  thecowboyway film ; similarity =  -0.009883145
# Sentence =  shrimponthebarbie ; similarity =  0.048434507
# Sentence =  theadventuresofbayoubilly ; similarity =  -0.030354965
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  cisforcorpse ; similarity =  0.009262274
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  puscifer ; similarity =  0.036914762
# Sentence =  visforviagra theremixes ; similarity =  0.009850621
# Sentence =  cisfor pleaseinsertsophomoricgenitaliareferencehere ; similarity =  0.12049299
# Sentence =  davidhockney ; similarity =  -0.009973968
# Sentence =  briansewell ; similarity =  0.006940528
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  dutchmantel ; similarity =  0.05904542
# Sentence =  clashofthechampions ; similarity =  0.081721015
# Sentence =  alexeyignashov ; similarity =  0.016703611
# Sentence =  danspivey ; similarity =  0.046522323
# Sentence =  kevinsullivan wrestler ; similarity =  0.03236105
# Sentence =  learningtheropes ; similarity =  0.009754673
# Sentence =  jimross ; similarity =  0.07456948
# Sentence =  listofnwaworldtagteamchampions ; similarity =  0.079127826
# Sentence =  listofextremechampionshipwrestlingalumni ; similarity =  0.10849921
# Sentence =  listoflegendsofwrestlingcharacters ; similarity =  0.05131217
# Sentence =  jushinthunderliger ; similarity =  0.035258073
# Sentence =  listofworldchampionshipwrestlingalumni ; similarity =  0.037479386
# Sentence =  listofprofessionalwrestlersbymmarecord ; similarity =  0.016777875
# Sentence =  listofwrestlingobservernewsletterawards ; similarity =  -0.024192257
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  raven wrestler ; similarity =  0.0883162
# Sentence =  mikepolchlopek ; similarity =  0.02621125
# Sentence =  ronsimmons ; similarity =  -0.019467847
# Sentence =  powerslam ; similarity =  -0.0054751136
# Sentence =  nikitakoloff ; similarity =  0.004526045
# Sentence =  salmanhashimikov ; similarity =  0.006200211
# Sentence =  michaelhayes wrestler ; similarity =  0.061783813
# Sentence =  sideudy ; similarity =  -0.012104308
# Sentence =  skandorakbar ; similarity =  0.06788287
# Sentence =  ringname ; similarity =  0.004498792
# Sentence =  mikerotunda ; similarity =  -0.03345224
# Sentence =  thebladerunners ; similarity =  0.088951126
# Sentence =  starrcade ; similarity =  -0.012450955
# Sentence =  triplecrownheavyweightchampionship ; similarity =  -0.010508105
# Sentence =  terrygordy ; similarity =  0.03502673
# Sentence =  universalwrestlingfederation billwatts ; similarity =  0.07793811
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  vampiro ; similarity =  0.06711401
# Sentence =  stevewilliams ; similarity =  0.021317491
# Sentence =  themiracleviolenceconnection ; similarity =  -0.032165755
# Sentence =  thebushwhackers ; similarity =  0.0442252
# Sentence =  wrestlingobservernewsletterhalloffame ; similarity =  0.1286766
# Sentence =  carlouellet ; similarity =  0.059671827
# Sentence =  dr death ; similarity =  -0.008087922
# Sentence =  billwatts ; similarity =  0.044929814
# Sentence =  bigbossman wrestler ; similarity =  0.06415535
# Sentence =  chi townrumble ; similarity =  0.05028505
# Sentence =  bigvanvader ; similarity =  -0.040297646
# Sentence =  barrywindham ; similarity =  0.052395374
# Sentence =  kentakobashi ; similarity =  0.054231122
# Sentence =  johnlaurinaitis ; similarity =  0.09112626
# Sentence =  lexluger ; similarity =  -0.047311973
# Sentence =  garyalbright ; similarity =  -0.03599658
# Sentence =  listofprowrestlingillustratedawards ; similarity =  0.07140864
# Sentence =  halloweenhavoc ; similarity =  0.0035780785
# Sentence =  jerryonly ; similarity =  0.10673267
# Sentence =  edferrara ; similarity =  -0.011457297
# Sentence =  listofwwealumni ; similarity =  0.086246945
# Sentence =  listofwcwworldtagteamchampions ; similarity =  0.039221115
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  paulorndorff ; similarity =  0.10253346
# Sentence =  onemangang ; similarity =  0.021245487
# Sentence =  powerbomb ; similarity =  0.038747374
# Sentence =  rikishi wrestler ; similarity =  0.08801586
# Sentence =  mitsuharumisawa ; similarity =  0.0020663997
# Sentence =  prowrestlingillustrated ; similarity =  0.10471244
# Sentence =  serenadeeb ; similarity =  -0.0034873006
# Sentence =  tazz ; similarity =  0.0066878153
# Sentence =  worldclasschampionshipwrestling ; similarity =  0.14065245
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  ōdōkeishō ; similarity =  0.012003353
# Sentence =  theodorelong ; similarity =  0.088947475
# Sentence =  starrcade ; similarity =  -0.012450955
# Sentence =  thevarsityclub ; similarity =  0.04109817
# Sentence =  wwfbrawlforall ; similarity =  0.0101565095
# Sentence =  starrcade ; similarity =  -0.012450955
# Sentence =  thegreatamericanbash ; similarity =  -0.04753902
# Sentence =  universalwrestlingfederation herbabrams ; similarity =  0.008025146
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  disfordeadbeat ; similarity =  0.121408746
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  yoonso hee ; similarity =  0.049939416
# Sentence =  separation statistics ; similarity =  -0.082018815
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  listofchineseculturalrelicsforbiddentobeexhibitedabroad ; similarity =  -0.03528951
# Sentence =  albaniansubversion ; similarity =  0.06096532
# Sentence =  midhatfrashëri ; similarity =  0.009611742
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  kirkwood atlanta ; similarity =  0.013727491
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  listoffathertedcharacters ; similarity =  -0.037158873
# Sentence =  fatherted ; similarity =  0.00267799
# Sentence =  listoffathertedepisodes ; similarity =  0.031940956
# Sentence =  entertainingfatherstone ; similarity =  0.05456061
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  gisforgumshoe ; similarity =  0.027704127
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  wherearewenow ; similarity =  -0.039870076
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  stationtostation ; similarity =  0.023549825
# Sentence =  thethinwhiteduke ; similarity =  0.050788194
# Sentence =  stage davidbowiealbum ; similarity =  0.010876139
# Sentence =  theriseandfallofziggystardustandthespidersfrommars ; similarity =  0.06768537
# Sentence =  v ; similarity =  0.06962579
# Sentence =  youngamericans album ; similarity =  0.00022610833
# Sentence =  symphonyno glass ; similarity =  0.04593161
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  neu ; similarity =  0.07033078
# Sentence =  philipglass ; similarity =  0.06069684
# Sentence =  mainpage ; similarity =  0.07606527
# Sentence =  senseofdoubt ; similarity =  -0.0116906185
# Sentence =  obliquestrategies ; similarity =  0.057653137
# Sentence =  low davidbowiealbum ; similarity =  0.08984361
# Sentence =  brianeno ; similarity =  0.106121294
# Sentence =  davidbowie ; similarity =  0.03854126
# Sentence =  davidbowiediscography ; similarity =  0.07271778
# Sentence =  aladdinsane ; similarity =  0.06409242
# Sentence =  beautyandthebeast davidbowiesong ; similarity =  0.09078838
# Sentence =  carlosalomar ; similarity =  0.014912775
# Sentence =  bestofbowie ; similarity =  0.14702536
# Sentence =  heroes davidbowiesong ; similarity =  0.11334588
# Sentence =  joethelion ; similarity =  0.015472766
# Sentence =  fripp eno ; similarity =  0.06560543
# Sentence =  hansatonstudio ; similarity =  0.056183822
# Sentence =  florianschneider ; similarity =  -0.013568394
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other twitter ; similarity =  0.034404803
# Sentence =  hunkydory ; similarity =  0.03446755
# Sentence =  letsdance davidbowiealbum ; similarity =  0.08051471
# Sentence =  heroes ; similarity =  0.0822455
# Sentence =  lodger album ; similarity =  0.020078773
# Sentence =  blackout davidbowiesong ; similarity =  0.16549762
# Sentence =   ; similarity =  0.054741997
# Sentence =  diamonddogs ; similarity =  0.09041062
# Sentence =  davidbowie ; similarity =  0.03854126
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  thenextday ; similarity =  0.037285533
# Sentence =  tonyvisconti ; similarity =  0.0013291537
# Sentence =  symphonyno glass ; similarity =  0.04593161
# Sentence =  theidiot album ; similarity =  0.03647702
# Sentence =  thesecretlifeofarabia ; similarity =  -0.0035376349
# Sentence =  vinceclarke ; similarity =  0.06895707
# Sentence =  themanwhosoldtheworld album ; similarity =  -0.010701652
# Sentence =  robertfrippdiscography ; similarity =  0.12002306
# Sentence =  robertfripp ; similarity =  -0.040168922
# Sentence =  neuköln ; similarity =  0.021217857
# Sentence =  lustforlife album ; similarity =  0.02048556
# Sentence =  mossgarden ; similarity =  0.056591116
# Sentence =  scarymonsters andsupercreeps ; similarity =  0.060570233
# Sentence =  iamthatiam ; similarity =  -0.062940076
# Sentence =  elizabethclareprophet ; similarity =  0.036855668
# Sentence =  legendsofmountshasta ; similarity =  -0.020905374
# Sentence =  listoffoundersofreligioustraditions ; similarity =  -0.030010048
# Sentence =  ascendedmasterteachings ; similarity =  0.05133803
# Sentence =  alicebailey ; similarity =  0.06039218
# Sentence =  robertlefevre ; similarity =  0.013979839
# Sentence =  st germain theosophy ; similarity =  0.06267945
# Sentence =  newage ; similarity =  -0.028857447
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  theaquariangospelofjesusthechrist ; similarity =  -0.03775644
# Sentence =  unitedstatesv ballard ; similarity =  0.049628127
# Sentence =  theosophicalsociety ; similarity =  0.0316324
# Sentence =  sevenrays ; similarity =  -0.03972625
# Sentence =  williamdudleypelley ; similarity =  -0.055894665
# Sentence =  theosophy ; similarity =  0.011512725
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other facebook ; similarity =  0.039253876
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other twitter ; similarity =  0.034404803
# Sentence =  churchuniversalandtriumphant ; similarity =  0.055792563
# Sentence =  adwellerontwoplanets ; similarity =  -0.031956587
# Sentence =  ascendedmaster ; similarity =  0.07376808
# Sentence =  guyballard ; similarity =  0.09265004
# Sentence =  iam ; similarity =  0.07324358
# Sentence =  greatwhitebrotherhood ; similarity =  -0.004233913
# Sentence =  listofnewreligiousmovements ; similarity =  0.040724736
# Sentence =  listofuforeligions ; similarity =  0.024968471
# Sentence =  justaroundtheriverbend ; similarity =  0.06837679
# Sentence =  forthefirsttimeinforever ; similarity =  0.029874615
# Sentence =  gothedistance ; similarity =  0.049001805
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  whenwillmylifebegin ; similarity =  0.050756864
# Sentence =  partofyourworld ; similarity =  0.056356337
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  ancapetrescu ; similarity =  0.010251902
# Sentence =  listofuniversitiesinromania ; similarity =  0.03459205
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  iisforinnocent ; similarity =  0.079216786
# Sentence =  fearofpop ; similarity =  0.036902044
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  jisforjudgment ; similarity =  0.029508924
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  prettyricky ; similarity =  0.005133089
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  jackstraw ; similarity =  -0.004263995
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  vladimirlenin ; similarity =  0.03015225
# Sentence =  thestateandrevolution ; similarity =  0.07154341
# Sentence =  ultra leftism ; similarity =  -0.00966692
# Sentence =  councilcommunism ; similarity =  0.019849485
# Sentence =  communistpartyofgreatbritain ; similarity =  0.045538593
# Sentence =  leftcommunism ; similarity =  0.02987444
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  lisforlawless ; similarity =  0.06793105
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  masterharold andtheboys ; similarity =  0.057169497
# Sentence =  eddieredmayne ; similarity =  -0.0071409605
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  masterharoldandtheboys ; similarity =  0.02195981
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  atholfugard ; similarity =  0.0067532873
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  woodlousespider ; similarity =  -0.013101503
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  misformalice ; similarity =  0.021676386
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  mounteerie ; similarity =  0.025124528
# Sentence =  mounteeriepts ; similarity =  0.05800552
# Sentence =  mounteerie album ; similarity =  0.022681901
# Sentence =  philelvrum ; similarity =  0.016395027
# Sentence =  masque themissionalbum ; similarity =  0.00930972
# Sentence =  themissiondiscography ; similarity =  0.030092405
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  tvxqalbumsdiscography ; similarity =  -0.008470028
# Sentence =  tvxqfilmography ; similarity =  0.06346469
# Sentence =  tvxq ; similarity =  0.114547655
# Sentence =  tvxqsinglesdiscography ; similarity =  0.02984967
# Sentence =  fiveintheblack ; similarity =  0.0047664787
# Sentence =  jungchanwoo ; similarity =  0.01226406
# Sentence =  heart mindandsoul tvxqalbum ; similarity =  0.08285323
# Sentence =  listofsongsrecordedbytvxq ; similarity =  0.006369689
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  luiginono ; similarity =  -0.04290952
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =   ; similarity =  0.054741997
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  oisforoutlaw ; similarity =  0.09307211
# Sentence =  qisforquarry ; similarity =  0.051397998
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  thescarletpimpernel ; similarity =  0.17378043
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  mainpage ; similarity =  0.07606527
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  lesliehoward actor ; similarity =  0.033471476
# Sentence =  listofworldwariifilms ; similarity =  0.018465009
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  marymorris ; similarity =  -0.027739521
# Sentence =  francisl sullivan ; similarity =  0.033188794
# Sentence =  davidtomlinson ; similarity =  -0.022389105
# Sentence =   ; similarity =  0.054741997
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  redterror ethiopia ; similarity =  0.11692883
# Sentence =  mainpage ; similarity =  0.07606527
# Sentence =  nebulaawardforbestshortstory ; similarity =  0.10006861
# Sentence =  run onsentence ; similarity =  0.124038436
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  ihavenomouth andimustscream ; similarity =  0.01653484
# Sentence =  listofjointwinnersofthehugoandnebulaawards ; similarity =  -0.025174884
# Sentence =  harlanellison ; similarity =  0.062831335
# Sentence =  harlequin ; similarity =  -0.018441236
# Sentence =  intime ; similarity =  -0.0049336473
# Sentence =  jellybean ; similarity =  0.044805903
# Sentence =  hugoawardforbestshortstory ; similarity =  0.03763831
# Sentence =  other yahoo ; similarity =  0.03174193
# Sentence =  paingodandotherdelusions ; similarity =  -0.028537028
# Sentence =  vforvendetta ; similarity =  0.034678977
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  risforricochet ; similarity =  -0.05070682
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  bergenairport flesland ; similarity =  0.09939112
# Sentence =  warsawchopinairport ; similarity =  0.078134656
# Sentence =  szczecin ; similarity =  0.071597286
# Sentence =  szczecinairport ; similarity =  0.10977168
# Sentence =  liverpooljohnlennonairport ; similarity =  -0.04224115
# Sentence =  mossairport rygge ; similarity =  0.03170168
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  świnoujście ; similarity =  0.064459726
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  eurolot ; similarity =  0.07290815
# Sentence =  dublinairport ; similarity =  -0.013801981
# Sentence =  listofairportsinpoland ; similarity =  0.029321466
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =   ; similarity =  0.054741997
# Sentence =   ; similarity =  0.054741997
# Sentence =  ryanairdestinations ; similarity =  0.09827593
# Sentence =  lutonairport ; similarity =  -0.027076874
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  therollingstones ; similarity =  -0.015431837
# Sentence =   ; similarity =  0.054741997
# Sentence =  therollingstonesdiscography ; similarity =  0.058755998
# Sentence =  takethe a train ; similarity =  0.14641516
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  stilllife disambiguation ; similarity =  -0.010237067
# Sentence =  timeisonmyside ; similarity =  0.03998618
# Sentence =  loveyoulive ; similarity =  -0.07442423
# Sentence =  goingtoago go song ; similarity =  0.07970022
# Sentence =  flashpoint album ; similarity =  0.06959269
# Sentence =  letsspendthenighttogether film ; similarity =  -0.0013959006
# Sentence =  caroemerald ; similarity =  0.0572484
# Sentence =  jakeholmes ; similarity =  0.062464938
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  dazedandconfused song ; similarity =  0.029763587
# Sentence =  chaddsfordtownship delawarecounty pennsylvania ; similarity =  0.18180488
# Sentence =  champferguson ; similarity =  0.061925996
# Sentence =  nightmare theacousticm s g ; similarity =  0.15245967
# Sentence =  michaelschenker ; similarity =  0.07896275
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  mcauleyschenkergroup ; similarity =  0.032334946
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  queenb ; similarity =  0.028801478
# Sentence =  puscifer ; similarity =  0.036914762
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  timcommerford ; similarity =  0.0095678335
# Sentence =  timalexander ; similarity =  -0.017874109
# Sentence =  alessandrocortini ; similarity =  -0.015722716
# Sentence =  conditionsofmyparole ; similarity =  0.074451126
# Sentence =  jarboe ; similarity =  0.020029707
# Sentence =  eddiemcclintock ; similarity =  -0.014262417
# Sentence =  gilsharone ; similarity =  0.10775964
# Sentence =  visforviagra theremixes ; similarity =  0.009850621
# Sentence =  cisfor pleaseinsertsophomoricgenitaliareferencehere ; similarity =  0.12049299
# Sentence =  aperfectcircle ; similarity =  0.045576897
# Sentence =  do notshootthemessenger ; similarity =  0.03261415
# Sentence =  lustmord ; similarity =  -0.0064670043
# Sentence =  maynardjameskeenandiscography ; similarity =  0.026894026
# Sentence =  maynardjameskeenan ; similarity =  0.026267003
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  wisforwasted ; similarity =  0.015353714
# Sentence =  uisforundertow ; similarity =  0.09180591
# Sentence =  suegrafton ; similarity =  0.068748966
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  kinseymillhone ; similarity =  -0.05755482
# Sentence =  puscifer ; similarity =  0.036914762
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  visforvagina ; similarity =  0.003511672
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other wikipedia ; similarity =  0.022668375
# Sentence =  other google ; similarity =  -0.013600783
# Sentence =  other twitter ; similarity =  0.034404803
# Sentence =  noretta ; similarity =  0.055046894
# Sentence =  ronpopeil ; similarity =  -0.008782271
# Sentence =  lump song ; similarity =  0.07274642
# Sentence =  mylittlepony friendshipismagic ; similarity =  0.09499285
# Sentence =  polkaparty ; similarity =  0.062416766
# Sentence =  parodymusic ; similarity =  0.043274168
# Sentence =  nashmetropolitan ; similarity =  0.035389304
# Sentence =  nerd ; similarity =  0.102933444
# Sentence =  mmmmmmmmmmmm ; similarity =  0.096518084
# Sentence =  nothinonyou ; similarity =  -0.04053392
# Sentence =  parodyinpopularmusic ; similarity =  -0.045977592
# Sentence =  polka ; similarity =  0.13615379
# Sentence =  royals song ; similarity =  0.09618286
# Sentence =  mickey song ; similarity =  0.08995169
# Sentence =  pattonoswalt ; similarity =  0.11634277
# Sentence =  lynwood california ; similarity =  0.047897417
# Sentence =  ridin ; similarity =  0.12544076
# Sentence =  pinkiepride ; similarity =  0.042475272
# Sentence =  mainpage ; similarity =  0.07606527
# Sentence =  parody ; similarity =  0.12927651
# Sentence =  mysharona ; similarity =  0.090159714
# Sentence =  mattl jones ; similarity =  0.082128085
# Sentence =  pianoman song ; similarity =  0.07965776
# Sentence =  poodlehat ; similarity =  0.084862456
# Sentence =  richardcheese ; similarity =  0.040980574
# Sentence =  oyvey ; similarity =  0.009250997
# Sentence =  moneyfornothing song ; similarity =  0.05177319
# Sentence =  sexyandiknowit ; similarity =  -0.00010654701
# Sentence =  onemoreminute ; similarity =  -0.0010540037
# Sentence =  morethanwords ; similarity =  -0.038782112
# Sentence =  loseyourself ; similarity =  0.055307556
# Sentence =  losingmyreligion ; similarity =  0.004597369
# Sentence =  scottraynor ; similarity =  0.018430665
# Sentence =  nationalspeechanddebateassociation ; similarity =  0.08261775
# Sentence =  mandatoryfun ; similarity =  -0.019843906
# Sentence =  prettyflyforarabbi ; similarity =  0.020431576
# Sentence =  ricky song ; similarity =  -0.00022604264
# Sentence =  mybologna ; similarity =  0.1427045
# Sentence =  petershukoff ; similarity =  0.04089073
# Sentence =  noveltysong ; similarity =  -0.04394043
# Sentence =  peterandthewolf weirdal yankovic wendycarlosalbum ; similarity =  0.06268916
# Sentence =  prettyfly forawhiteguy ; similarity =  0.08694545
# Sentence =  lola song ; similarity =  0.011868738
# Sentence =  rcarecords ; similarity =  0.16215263
# Sentence =  tomlehrer ; similarity =  -0.00814145
# Sentence =  tonyaharding ; similarity =  -0.042726714
# Sentence =  thehotwivesoforlando ; similarity =  0.070655234
# Sentence =  tacky song ; similarity =  0.013853421
# Sentence =  we arenotgonnatakeit twistedsistersong ; similarity =  0.08251555
# Sentence =  theessential weirdal yankovic ; similarity =  0.075058095
# Sentence =  yugoslavamerican ; similarity =  0.06864249
# Sentence =  taxman ; similarity =  0.0977282
# Sentence =  timandericawesomeshow greatjob ; similarity =  0.085152425
# Sentence =  sussudio ; similarity =  -0.00064451183
# Sentence =  thewrongferarri ; similarity =  0.070478685
# Sentence =  thesmelloffear ; similarity =  0.013801251
# Sentence =  trappedinthedrive thru ; similarity =  0.029396987
# Sentence =  thelatelateshowwithcraigferguson ; similarity =  0.08807396
# Sentence =  thegrimadventuresofbilly mandy videogame ; similarity =  0.11930429
# Sentence =  thenightsantawentcrazy ; similarity =  0.08478719
# Sentence =  twinkie ; similarity =  0.158929
# Sentence =  thedrewcareyshow ; similarity =  0.016423333
# Sentence =  starwarskid ; similarity =  0.13847013
# Sentence =  other bing ; similarity =  0.023170898
# Sentence =  spam food ; similarity =  0.21127205
# Sentence =  you arepitiful ; similarity =  0.17676695
# Sentence =  you arebeautiful ; similarity =  0.095314726
# Sentence =  uhf film ; similarity =  0.07353064
# Sentence =  waynebergeron ; similarity =  -0.047335364
# Sentence =  smellsliketeenspirit ; similarity =  0.058484145
# Sentence =  weird ; similarity =  0.10251292
# Sentence =  victoriajackson ; similarity =  -0.031869892
# Sentence =  trinidadsilva ; similarity =  0.052728366
# Sentence =  tobyturner ; similarity =  0.035862915
# Sentence =  straightouttacompton ; similarity =  0.020049445
# Sentence =  threegaysofthecondo ; similarity =  -0.0056515574
# Sentence =  theadventuresofcaptainunderpants ; similarity =  0.013385968
# Sentence =  thesagabegins ; similarity =  0.11578968
# Sentence =  wikipedia ; similarity =  0.012978619
# Sentence =   ; similarity =  0.054741997
# Sentence =  tomorrow tvseries ; similarity =  0.012165641
# Sentence =  yogabbagabba ; similarity =  0.025322514
# Sentence =  topsecret ; similarity =  0.012169081
# Sentence =  white nerdy ; similarity =  0.08275617
# Sentence =  straightouttalynwood ; similarity =  0.040491365
# Sentence =  volcanoentertainment ; similarity =  0.057732828
# Sentence =  theweirdalshow ; similarity =  0.059695534
# Sentence =  spyhard song ; similarity =  0.059576064
# Sentence =  superbowlxlixhalftimeshow ; similarity =  0.1082765
# Sentence =  other other ; similarity =  0.030498616
# Sentence =  other facebook ; similarity =  0.039253876
# Sentence =  badhairday ; similarity =  0.012961069
# Sentence =  chopsuey song ; similarity =  0.031690307
# Sentence =  chamillionaire ; similarity =  -0.023555042
# Sentence =  comedybang bang ; similarity =  0.09649587
# Sentence =  downwiththesickness ; similarity =  0.004050202
# Sentence =  dollmaker comics ; similarity =  -0.001259908
# Sentence =  bandaid band ; similarity =  0.11384094
# Sentence =  allansherman ; similarity =  0.041482415
# Sentence =  downey california ; similarity =  -0.0155479405
# Sentence =  blackorwhite ; similarity =  0.009836611
# Sentence =  craigslist ; similarity =  0.06702149
# Sentence =  dcuniverseanimatedoriginalmovies ; similarity =  0.050546266
# Sentence =  comedymusic ; similarity =  -0.0023807173
# Sentence =  colawars ; similarity =  0.051885117
# Sentence =  beck ; similarity =  0.15247722
# Sentence =  anotheroneridesthebus ; similarity =  -0.06415266
# Sentence =  comedyrock ; similarity =  -0.020474713
# Sentence =  albuquerque song ; similarity =  0.020634884
# Sentence =  animalman ; similarity =  0.008189297
# Sentence =  backatthebarnyard ; similarity =  0.0994305
# Sentence =  alpocalypse ; similarity =  0.02291223
# Sentence =  atlanticrecords ; similarity =  0.021095635
# Sentence =   ; similarity =  0.054741997
# Sentence =  closebutnocigar ; similarity =  -0.019676678
# Sentence =  christmasatgroundzero ; similarity =  -0.025250325
# Sentence =  drunkhistory ; similarity =  0.06297629
# Sentence =  weirdalyankovicvideography ; similarity =  0.054179784
# Sentence =  couchpotato song ; similarity =  0.013362542
# Sentence =  billplympton ; similarity =  0.032406263
# Sentence =  d ; similarity =  0.018047528
# Sentence =  weirdalyankoviclive thealpocalypsetour ; similarity =  0.06559314
# Sentence =  weirdalyankovic album ; similarity =  0.007311425
# Sentence =  comedyhiphop ; similarity =  -0.006489075
# Sentence =  weirdalyankovicsgreatesthits ; similarity =  0.077836245
# Sentence =  dr demento ; similarity =  -0.008015317
# Sentence =  albuquerque newmexico ; similarity =  0.021217752
# Sentence =  aishatyler ; similarity =  0.015268003
# Sentence =  coolio ; similarity =  0.00013240051
# Sentence =  cledust judd ; similarity =  0.017937373
# Sentence =  doge meme ; similarity =  0.11545904
# Sentence =  canadianidiot ; similarity =  -0.03580161
# Sentence =  daretobestupid song ; similarity =  0.052367385
# Sentence =  crashtestdummies ; similarity =  -0.006545433
# Sentence =  cherrypie warrantsong ; similarity =  -0.04934713
# Sentence =  dweezilzappa ; similarity =  0.01585758
# Sentence =  donnyosmond ; similarity =  0.032934777
# Sentence =  dcnationshorts ; similarity =  0.074645065
# Sentence =  closingtime semisonicsong ; similarity =  0.023806943
# Sentence =  claudiao wouldoherty ; similarity =  0.07852379
# Sentence =  frankzappa ; similarity =  0.0411143
# Sentence =  eyeofthetiger ; similarity =  0.036718737
# Sentence =  ironic song ; similarity =  0.008445482
# Sentence =  fireflies owlcitysong ; similarity =  0.091488734
# Sentence =  ghettosupastar thatiswhatyouare ; similarity =  -0.05057929
# Sentence =  listofhowimetyourmothercharacters ; similarity =  0.053404965
# Sentence =  felixthecat ; similarity =  0.050029736
# Sentence =  heresjohnny ; similarity =  0.06477225
# Sentence =  hiptobesquare ; similarity =  -0.061335094
# Sentence =  jackblack ; similarity =  0.062119443
# Sentence =  listoflilo stitch theseriesepisodes ; similarity =  0.045609903
# Sentence =  it isallaboutthepentiums ; similarity =  0.03450876
# Sentence =  kristenschaal ; similarity =  0.09942399
# Sentence =  likeasurgeon weirdal yankovicsong ; similarity =  0.01920327
# Sentence =  johnmorrison wrestler ; similarity =  0.051006652
# Sentence =  headlinenews song ; similarity =  0.043501247
# Sentence =  happy pharrellwilliamssong ; similarity =  0.049688213
# Sentence =  i willbethereforyou therembrandtssong ; similarity =  0.24270776
# Sentence =  jizzinmypants ; similarity =  0.12527677
# Sentence =  gangstasparadise ; similarity =  -0.002656616
# Sentence =  listof weirdal yankovicpolkamedleys ; similarity =  0.03971437
# Sentence =  ican notdance ; similarity =  0.1117811
# Sentence =  listofitalian americanentertainers ; similarity =  -0.06669898
# Sentence =  handy song ; similarity =  -0.040479045
# Sentence =  footloose song ; similarity =  0.04779999
# Sentence =  eminem ; similarity =  0.10745137
# Sentence =  frankieyankovic ; similarity =  0.022574248
# Sentence =  evenworse ; similarity =  -0.009747065
# Sentence =  gotmymindsetonyou ; similarity =  -0.0006960593
# Sentence =  janiesgotagun ; similarity =  0.093458354
# Sentence =  jeopardy ; similarity =  0.076120906
# Sentence =  liamlynch musician ; similarity =  -0.07223882
# Sentence =   ; similarity =  0.054741997
# Sentence =   ; similarity =  0.054741997
# Sentence =  keegan michaelkey ; similarity =  0.09753294
# Sentence =  georgecarlin ; similarity =  -0.020797424
# Sentence =  grammyawardforbestconceptmusicvideo ; similarity =  -0.017219508
# Sentence =  emophilips ; similarity =  -0.0041311975
# Sentence =  johnnybravo ; similarity =  0.063173845
# Sentence =  ilostonjeopardy ; similarity =  0.056964546
# Sentence =   ; similarity =  0.054741997
# Sentence =  listofrcarecordsartists ; similarity =  0.0846569
# Sentence =  jerryspringer ; similarity =  0.037976373
# Sentence =  gamegrumps ; similarity =  0.127055
# Sentence =  electricavenue song ; similarity =  0.025364622
# Sentence =  heyjude ; similarity =  0.08550118
# Sentence =  foil song ; similarity =  0.085890785
# Sentence =  listofcalpolyatsanluisobispoalumni ; similarity =  -0.0042915186
# Sentence =  liberiangirl ; similarity =  -0.0085040685
# Sentence =  listofpolkaartists ; similarity =  0.037488513
# Sentence =  listofvolcanoentertainmentartists ; similarity =  0.21745425
# Sentence =  listofsongsrecordedby weirdal yankovic ; similarity =  0.013746439
# Sentence =  listofvegans ; similarity =  0.06305739
# Sentence =  listofsatiristsandsatires ; similarity =  0.11295823
# Sentence =  altv ; similarity =  0.07694556
# Sentence =  alapalooza ; similarity =  0.009272154
# Sentence =  donpardo ; similarity =  0.009978594
# Sentence =  callmemaybe ; similarity =  0.033276994
# Sentence =  weirdalyankoviclive ; similarity =  0.057942517
# Sentence =  weirdalyankovic ; similarity =  -0.016507357
# Sentence =  auto tune ; similarity =  0.03543326
# Sentence =  amishparadise ; similarity =  0.047706626
# Sentence =  weirdalyankovicdiscography ; similarity =  0.09825866
# Sentence =  batmanvs robin ; similarity =  0.09050682
# Sentence =  ebay song ; similarity =  -0.009004444
# Sentence =  aaronpaul ; similarity =  0.043601397
# Sentence =  eatit ; similarity =  0.0627978
# Sentence =  bohemianrhapsody ; similarity =  0.14705175
# Sentence =  charlesnelsonreilly ; similarity =  -0.00062990375
# Sentence =  eatit weirdal yankovicalbum ; similarity =  0.061239064
# Sentence =  addictedtolove song ; similarity =  0.04021419
# Sentence =  eddievedder ; similarity =  0.0011956561
# Sentence =  batman thebraveandthebold ; similarity =  0.13179925
# Sentence =  daretobestupid ; similarity =  -0.043744087
# Sentence =  do notdownloadthissong ; similarity =  0.016437719
# Sentence =  americanpie song ; similarity =  0.045179076
# Sentence =  behindthemusic ; similarity =  0.08284556
# Sentence =  benfolds ; similarity =  0.0078099826
# Sentence =  anotheroneridesthebus ep ; similarity =  0.0022501296
# Sentence =  bedrockanthem ; similarity =  0.041443236
# Sentence =  beatit ; similarity =  0.05153095
# Sentence =  blurredlines ; similarity =  0.16371982
# Sentence =  craigslist song ; similarity =  0.06039519
# Sentence =  bad michaeljacksonsong ; similarity =  0.070905365
# Sentence =  californiapolytechnicstateuniversity ; similarity =  0.07300287
# Sentence =  apologetix ; similarity =  0.069101706
# Sentence =  accordion ; similarity =  0.08381224
# Sentence =  listofkeytarists ; similarity =  0.02112308
# Sentence =  listofbackmaskedmessages ; similarity =  0.166535
# Sentence =  liveandletdie song ; similarity =  0.069537744
# Sentence =  listofcomedians ; similarity =  0.010965823
# Sentence =  johnandlorenabobbitt ; similarity =  0.114958495
# Sentence =  howimetyourmother ; similarity =  0.031764526
# Sentence =  galavant ; similarity =  0.013608521
# Sentence =  hiddentrack ; similarity =  0.08453783
# Sentence =  ericstonestreet ; similarity =  0.073399514
# Sentence =  lasagna song ; similarity =  0.30456582
# Sentence =  hauntedlighthouse ; similarity =  0.013305878
# Sentence =  gump song ; similarity =  0.117692366
# Sentence =  iloverockyroad ; similarity =  -0.0003330614
# Sentence =  itouchmyself ; similarity =  0.07724692
# Sentence =  iceicebaby ; similarity =  0.12529035
# Sentence =  listofthelatelateshowepisodes ; similarity =  0.024968538
# Sentence =  iwantitthatway ; similarity =  -0.008236312
# Sentence =  jimwest guitarist ; similarity =  0.092048936
# Sentence =  fannypack ; similarity =  0.09868542
# Sentence =  epicrapbattlesofhistory ; similarity =  0.08584109
# Sentence =  grammyawardforbestcomedyalbum ; similarity =  -0.0010279587
# Sentence =  jamesblunt ; similarity =  0.04888326
# Sentence =  icebucketchallenge ; similarity =  0.04865744
# Sentence =  iwantanewdrug ; similarity =  0.18518384
# Sentence =  listofmylittlepony friendshipismagicepisodes ; similarity =  0.045841042
# Sentence =  lameclaimtofame ; similarity =  0.02224847
# Sentence =  kidnappedbydanger ; similarity =  -0.008276638
# Sentence =  listofmylittlepony friendshipismagiccharacters ; similarity =  0.035227
# Sentence =  judytenuta ; similarity =  0.10364308
# Sentence =  hueylewisandthenews ; similarity =  -0.047901083
# Sentence =  jonschwartz drummer ; similarity =  0.12181689
# Sentence =  falco musician ; similarity =  -0.06940205
# Sentence =  heresjohnny song ; similarity =  0.055329923
# Sentence =  jordanpeele ; similarity =  -0.0012781728
# Sentence =  gilbertgottfried ; similarity =  -0.0026146427
# Sentence =  isaacnewtoninpopularculture ; similarity =  0.06874772
# Sentence =  joanjett ; similarity =  0.024502732
# Sentence =  jurassicpark song ; similarity =  0.035698332
# Sentence =  internetleaks ; similarity =  -0.033492625
# Sentence =  listofepicrapbattlesofhistoryepisodes ; similarity =  0.030572722
# Sentence =  letsgetitstarted ; similarity =  0.027829826
# Sentence =  listofthesimpsonsgueststars ; similarity =  0.05967952
# Sentence =  hurley album ; similarity =  0.016832115
# Sentence =  fat song ; similarity =  0.04839742
# Sentence =  other empty ; similarity =  0.019568266
# Sentence =  wiki ; similarity =  0.001834031
# Sentence =  thenakedgun fromthefilesofpolicesquad ; similarity =  0.026051471
# Sentence =  thesagabegins album ; similarity =  0.06640538
# Sentence =  thebiggestballoftwineinminnesota ; similarity =  0.02058337
# Sentence =  weaselstompingday ; similarity =  -0.013790616
# Sentence =  thesafetydance ; similarity =  -0.0062661804
# Sentence =  whateveryoulike weirdal yankovicsong ; similarity =  0.11286129
# Sentence =  whiplash ; similarity =  0.025917955
# Sentence =  thenakedgun ; similarity =  -0.018030427
# Sentence =  timber song ; similarity =  0.05458659
# Sentence =  yankovic ; similarity =  0.083270006
# Sentence =  stevejay ; similarity =  0.044414826
# Sentence =  vannawhite ; similarity =  0.0061785774
# Sentence =  wallykazam ; similarity =  0.055507574
# Sentence =   ; similarity =  0.054741997
# Sentence =  thefoodalbum ; similarity =  0.022252496
# Sentence =  yoda song ; similarity =  0.11373977
# Sentence =  wordgirl ; similarity =  0.08535088
# Sentence =  wordcrimes ; similarity =  0.011468205
# Sentence =  tonyhawk ; similarity =  0.082533926
# Sentence =  ucan nottouchthis ; similarity =  0.026178619
# Sentence =  thriftshop ; similarity =  0.029896434
# Sentence =  superbowlxlix ; similarity =  0.15652785
# Sentence =  youdo notlovemeanymore weirdal yankovicsong ; similarity =  0.016673554
# Sentence =  thefinalinsult ; similarity =  -0.029943759
# Sentence =   ; similarity =  0.054741997
# Sentence =  raymanzarek ; similarity =  0.018046554
# Sentence =  sethgreen ; similarity =  0.066772036
# Sentence =  partyintheu s a ; similarity =  -0.007158504
# Sentence =  loser becksong ; similarity =  0.02571256
# Sentence =  r leeermey ; similarity =  0.05178562
# Sentence =  starwars ; similarity =  0.11937896
# Sentence =  rickderringer ; similarity =  0.00040119136
# Sentence =  scooby doo ; similarity =  0.17021655
# Sentence =  spikejones ; similarity =  0.010145185
# Sentence =  prince musician ; similarity =  -0.022588877
# Sentence =  spyhard ; similarity =  -0.028620787
# Sentence =  lynwoodhighschool ; similarity =  0.097811826
# Sentence =  offthedeepend ; similarity =  0.0009521794
# Sentence =  mad magazine ; similarity =  0.07293057
# Sentence =  richardstallman ; similarity =  0.125086
# Sentence =  margaretcho ; similarity =  0.08767672
# Sentence =  oneweek song ; similarity =  0.037879415
# Sentence =  mylittlepony friendshipismagic ; similarity =  0.09499285
# Sentence =  spaceghostcoasttocoast ; similarity =  0.0038871705
# Sentence =  rayoflight song ; similarity =  0.04873851
# Sentence =   ; similarity =  0.054741997
# Sentence =  smellslikenirvana ; similarity =  0.078317866
# Sentence =  nationalenquirer ; similarity =  0.018418986
# Sentence =  radioactive imaginedragonssong ; similarity =  0.06314491
# Sentence =  runningwithscissors weirdal yankovicalbum ; similarity =  0.066551164
# Sentence =  pokémon ; similarity =  0.12003953
