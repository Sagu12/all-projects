# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagu12/all-projects/blob/master/sentiment_anaysis_using_polyglot_and_vader_for_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json

# %%
df= pd.read_json("/content/drive/MyDrive/enhanceduserdatabeta1.json", lines=True)

# %%
df.head()
# Out:
#                   _index  ...                                            _source
# 0  enhanceduserdatabeta1  ...  {'publisher_id': '49491', 'date': '2020-04-22'...
# 1  enhanceduserdatabeta1  ...  {'publisher_id': '49491', 'date': '2020-04-22'...
# 2  enhanceduserdatabeta1  ...  {'publisher_id': '49491', 'date': '2020-04-22'...
# 3  enhanceduserdatabeta1  ...  {'publisher_id': '49491', 'date': '2020-04-22'...
# 4  enhanceduserdatabeta1  ...  {'publisher_id': '49491', 'date': '2020-04-22'...
#
# [5 rows x 5 columns]

# %%
source=pd.json_normalize(df._source)

# %%
source.head()
# Out:
#   publisher_id        date country  ...  tag publishDatev1 section
# 0        49491  2020-04-22          ...  NaN           NaN     NaN
# 1        49491  2020-04-22          ...  NaN           NaN     NaN
# 2        49491  2020-04-22          ...  NaN           NaN     NaN
# 3        49491  2020-04-22          ...  NaN           NaN     NaN
# 4        49491  2020-04-22   India  ...  NaN           NaN     NaN
#
# [5 rows x 76 columns]

# %%
con= pd.concat([df, source], axis=1)

# %%
con.audience_segment.value_counts()
# Out:
#                              68617
# art.and.entertainment         9457
# technology.and.computing      7000
# health.and.fitness            6387
# law.govt.and.politics         5584
# society                       3516
# religion.and.spirituality     1763
# news                          1329
# finance                        935
# business.and.industrial        623
# shopping                       410
# sports                         396
# home.and.garden                385
# science                        304
# style.and.fashion              255
# travel                         202
# food.and.drink                 137
# education                      115
# family.and.parenting            75
# automotive.and.vehicles         47
# hobbies.and.interests           36
# pets                            12
# careers                         12
# real.estate                      3
# Name: audience_segment, dtype: int64

# %%
li= ["refcurrentoriginal", "audience_segment", "engagementTime", "gender"]
def select_columns(data_frame, column_names):
    new_frame = data_frame.loc[:, column_names]
    return new_frame

new= select_columns(con,li)

# %%
new.head()
# Out:
#                                   refcurrentoriginal  ...  gender
# 0  https://m.aajtak.in/khabare-ab-tak/story/caste...  ...  female
# 1  https://m.aajtak.in/karyakrams/das-tak/video/-...  ...    male
# 2  https://m.aajtak.in/national/video/sapna-chaud...  ...    male
# 3  https://m.aajtak.in/movie-masala/news-on-films...  ...    male
# 4  https://m.aajtak.in/karyakrams/kismat-konnecti...  ...  female
#
# [5 rows x 4 columns]

# %%
new["refcurrentoriginal"]= new["refcurrentoriginal"].astype("str")

# %%
new['result'] = new['refcurrentoriginal'].map(lambda x: x.lstrip('https://m. www').rstrip('aAbBcC'))

# %%
import re
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download("popular")

# %%
from nltk.stem import WordNetLemmatizer
ps= WordNetLemmatizer()
corpus=[]
for i in range(0,len(new)):
  print(i)
  review= re.sub("[^a-zA-Z]", " ", new["result"][i])
  review= review.lower()
  review= review.split()
  review= [ps.lemmatize(word) for word in review if not word in stopwords.words("english")]
  review= " ".join(review)
  corpus.append(review)

# %%
new["news"]= corpus

# %%
new.head()
# Out:
#                                   refcurrentoriginal  ...                                               news
# 0  https://m.aajtak.in/khabare-ab-tak/story/caste...  ...  aajtak khabare ab tak story caste based census...
# 1  https://m.aajtak.in/karyakrams/das-tak/video/-...  ...    aajtak karyakrams da tak video crime woman stop
# 2  https://m.aajtak.in/national/video/sapna-chaud...  ...  aajtak national video sapna chaudhary dance sh...
# 3  https://m.aajtak.in/movie-masala/news-on-films...  ...  aajtak movie masala news film story shahid kap...
# 4  https://m.aajtak.in/karyakrams/kismat-konnecti...  ...  aajtak karyakrams kismat konnection video kism...
#
# [5 rows x 6 columns]

# %%
pip install polyglot

# %%
pip install pyicu

# %%
pip install Morfessor

# %%
pip install pycld2

# %%
from polyglot.text import Word, Text

# %%
# !polyglot download sentiment2.en
# Out:
# [polyglot_data] Downloading package sentiment2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data]   Package sentiment2.en is already up-to-date!

# %%
new.isna().sum()
# Out:
# refcurrentoriginal       0
# audience_segment         0
# engagementTime        8116
# gender                8129
# result                   0
# news                     0
# dtype: int64

# %%
new["news"]= new["news"].astype("str")

# %%
new= new.dropna(axis=0)

# %%
i=0
for i in new.news:
  p = (i)
  print(p)

# %%
from polyglot.text import cached_property, Text
class TextOverride(Text):
    @cached_property
    def polarity(self):
        """Return the polarity score as a float within the range [-1.0, 1.0]
        """
        scores = [w.polarity for w in self.words if w.polarity != 0]
        if len(scores) == 0:
            return 0.0
        return sum(scores) / float(len(scores))

# %%
over= TextOverride(new.news[89])

# %%
over.polarity
# Out:
# -1.0

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
for i in new.news:


  print(analyzer.polarity_scores(i))
# Out:
# Streaming output truncated to the last 5000 lines.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...
